# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import torch
import torchvision
import torchvision.transforms as transforms
from dataloaders import get_datasets

# %%
## load datasets
train_set, val_set = get_datasets("data/small_data.csv", "data/train/", batch_size=11)

# %%
df = pd.read_csv("data/categories.csv")
df.head()
classes = df[['car_name']].to_numpy()

# %%
# functions to show an image
def imshow(img):
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()


# get some random training images
dataiter = iter(trainloader)
images, labels, paths = dataiter.next()

# show images
imshow(torchvision.utils.make_grid(images))
# print labels
print(' '.join('%5s' % classes[labels[j]] for j in range(2)))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ['Ram C/V Cargo Van Minivan 2012'] ['Isuzu Ascender SUV 2008']

# %%
it = iter(testloader)
for i in range(size['train']):
    images, labels, paths = it.next()
    #print(len(images), labels, paths)
    images = images.numpy()
    print(images.shape)
    break;
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-85cddc11b753> in <module>
# ----> 1 it = iter(testloader)
#       2 for i in range(size['train']):
#       3     images, labels, paths = it.next()
#       4     #print(len(images), labels, paths)
#       5     images = images.numpy()
#
# NameError: name 'testloader' is not defined

# %%
### test k means
from classifiers import KNN

# %%
images,s ,s = train_set[0]

# %%
images = np.squeeze(images)
print(images.shape)
# Out:
# torch.Size([3, 128, 128])

# %%
k = KNN(train_set,val_set)

# %%
k.train()

# %%
k.test()
# Out:
# (array([[276.23585191, 283.61378813],
#        [284.53922702, 292.81402898],
#        [265.95349259, 277.86165306],
#        [239.76300936, 256.42044048],
#        [228.12232049, 238.6282158 ],
#        [214.85927209, 216.61750077],
#        [256.57007961, 278.61878743],
#        [341.13993602, 342.34083231],
#        [320.93491859, 374.72281667],
#        [280.43999146, 285.77390249],
#        [273.07221944, 322.39688827]]), array([[12,  7],
#        [39, 29],
#        [ 8,  3],
#        [21, 29],
#        [ 7, 25],
#        [21, 11],
#        [26,  8],
#        [35,  5],
#        [ 2, 34],
#        [ 3,  8],
#        [39,  8]]))
